# %% [markdown]
# # ASSIGNMENT-5
#
# # DECISION TREE

# %% [markdown]
# **Question No1:** What is a Decision Tree, and how does it work
#
# **Answer:**
#
# A Decision Tree is a supervised machine learning algorithm used for both classification and regression tasks. It models data through a tree-like structure where each internal node represents a decision based on a feature, each branch represents the outcome of that decision, and the leaf nodes represent the final output (classification or value). The tree splits the data into subsets based on the features that provide the most information (or best decision-making ability) at each level.
#
# Key Components:
#
# Root Node: Represents the entire dataset, which is split based on a feature.
# Internal Nodes: Each internal node represents a decision or test on an attribute.
# Branches: These are the outcomes of the decision in the node, leading to further splits.
# Leaf Nodes: The terminal nodes, which give the final output (prediction).
#
# How It Works:
#
# Data Splitting: Starting from the root node, the data is split into subsets based on the best feature (using metrics like Gini Impurity, Information Gain, or Chi-square for classification, or Variance Reduction for regression). The goal is to reduce uncertainty at each split.
#
# Recursion: The process of splitting continues recursively for each subset of data, with the tree growing deeper as more nodes are added. This continues until a stopping criterion is met (e.g., when all data points in a subset belong to the same class, or a max depth is reached).
#
# Decision Making: At each internal node, the tree decides which feature to test based on the feature that best separates the data, ultimately leading to a classification or regression result at the leaf nodes.

# %% [markdown]
# **Question No2:** What are impurity measures in Decision Trees
#
# **Answer:**
#
# In Decision Trees, impurity measures are used to quantify how mixed or impure the data is at each node in the tree. The goal of a Decision Tree algorithm is to split the data at each node in a way that minimizes impurity, making each node as pure (or homogeneous) as possible. An impure node means that the data at that node contains a mix of different classes, while a pure node means that all the data points belong to a single class.
#
# There are several common impurity measures used to guide the splitting process in Decision Trees, and they each measure how "impure" a set of data is in different ways. Here are the most commonly used impurity measures:
#
# 1. Gini Impurity
#
# Used for: Classification problems.
# Formula:
#
# 𝐺
# 𝑖
# 𝑛
# 𝑖
# =
# 1
# −
# ∑
# 𝑖
# =
# 1
# 𝐶
# 𝑝
# 𝑖
# 2
#
# Where
# 𝑝
# 𝑖 is the probability (or proportion) of class
# 𝑖 in a given node, and
# C is the total number of classes.
#
# Interpretation: The Gini impurity measures the likelihood of a random element being misclassified if it is randomly labeled according to the class distribution at the node.
#
# A Gini Impurity of 0 means the node is perfectly pure (all data points belong to a single class).
# A Gini Impurity of 0.5 indicates maximum impurity, where the data is evenly split between classes.
#
# Example: If a node has 70% of class A and 30% of class B, the Gini impurity would be lower than a node with 50% of each class.
#
# 2. Entropy (Information Gain)
#
# Used for: Classification problems.
# Formula:
#
# Entropy=−
# i=1
# ∑
# C
# ​
#  p
# i
# ​
#  log
# 2
# ​
#  (p
# i
# ​
#  )
# Where
# p
# i is the probability of class
# i in the node, and
# C is the total number of classes.
#
# Interpretation: Entropy measures the uncertainty or disorder of a dataset. The more evenly distributed the classes are, the higher the entropy.
# An entropy of 0 means the node is pure (all examples belong to a single class).
# An entropy of 1 means the classes are perfectly mixed, leading to maximum uncertainty.
# Information Gain: This is how much entropy is reduced after a split. The algorithm will choose the feature that provides the highest information gain (i.e., the largest reduction in entropy) when splitting the dataset.
#
# 3. Classification Error (Misclassification Rate)
#
# Used for: Classification problems.
# Formula:
#
# Error=1−max(p
# 1
# ​
#  ,p
# 2
# ​
#  ,…,p
# C
# ​
#  )
#
# Where
# 𝑝
# 𝑖
# p
# i
# ​
#   is the proportion of class
# 𝑖
# i in the node, and
# 𝐶
# C is the number of classes.
#
# Interpretation: The classification error is the fraction of misclassified points in a node. It is simple but less commonly used than Gini or entropy because it doesn’t provide as much nuance in deciding the best splits.
# 0 error means the node is pure (all data points belong to a single class).
# Higher error means the node is impure (more mixed classes).
#
# Limitations: The classification error measure tends to be less sensitive to class distributions than Gini or Entropy, and often leads to deeper trees.
#
# 4. Variance (for Regression Trees)
#
# Used for: Regression problems (when predicting continuous values).
# Formula:
#
# Variance=
# N
# 1
# ​
#
# i=1
# ∑
# N
# ​
#  (y
# i
# ​
#  −
# y
# ˉ
# ​
#  )
# 2
#
# Where
# 𝑦
# 𝑖
# y
# i
# ​
#   are the target values (continuous) of the data points in the node,
# 𝑦
# ˉ
# y
# ˉ
# ​
#   is the mean target value of the data points in the node, and
# 𝑁
# N is the number of data points in the node.
#
# Interpretation: For regression trees, the variance measures how spread out the target values are. A node with low variance means that the target values are close to each other (the node is pure), while high variance means the values are spread out.
# A variance of 0 means the node is pure (all target values are the same).
# A high variance means the data points in the node have diverse values.
#
# Comparing Impurity Measures:
# Gini Impurity vs. Entropy: Both are used for classification tasks and tend to behave similarly in practice, with Gini being faster to compute. Entropy may be slightly more sensitive to data distributions, but the difference in performance is often negligible.
#
# Variance: For regression tasks, variance is the most natural impurity measure, as the objective is to predict a continuous value. It directly measures how varied the target values are in the node.
#
# How Impurity Measures Influence Decision Tree Growth:
#
# During the decision tree’s training process, the algorithm evaluates potential splits at each node based on how well they reduce impurity. The split that results in the lowest impurity is chosen to create the next set of branches.
# For classification tasks, the decision tree will prefer splits that reduce Gini Impurity or Entropy the most, and for regression tasks, it will focus on reducing variance.

# %% [markdown]
# **Question No3:** What is the mathematical formula for Gini Impurity
#
# **Answer:**
#
# The mathematical formula for Gini Impurity is:
#          c
# Gini=1−  ∑ pi2
#         i=1
#
# Where:
#
# C is the number of classes in the dataset.
#
# pi is the proportion (or probability) of class i in the node.

# %% [markdown]
# **Question No4:** What is the mathematical formula for Entropy
#
# **Answer:**
#
# The mathematical formula for Entropy is:
#
# Entropy=−
# i=1
# ∑
# C
# ​
#  p
# i
# ​
#  log
# 2
# ​
#  (p
# i
# ​
#  )
#
# Where:
#
# C is the number of classes in the dataset.
#
# p i is the proportion (or probability) of class i in the node.

# %% [markdown]
# **Question No5:** What is Information Gain, and how is it used in Decision Trees
#
# **Answer:**
#
# Information Gain (IG) is a key concept used in Decision Trees, specifically for classification tasks. It measures how much uncertainty (entropy) is reduced after a dataset is split based on a particular feature. Information Gain is used to select the best feature to split on at each node in the decision tree.
#
# Formula for Information Gain:
# The formula for Information Gain is:
#
# InformationGain=Entropy(parent)−
# i=1
# ∑
# n
# ∣S∣
# ∣S
# i
# ​
#  ∣
# ​
#  ×Entropy(S
# i
# ​
#  )
#
# Where:
#
# Entropy(parent) is the entropy of the dataset before the split (i.e., the impurity of the parent node).
# 𝑆
# 𝑖
# S
# i
# ​
#   represents the subsets of data after the split.
# ∣
# 𝑆
# 𝑖
# ∣
# ∣S
# i
# ​
#  ∣ is the size of subset
# 𝑆
# 𝑖
# S
# i
# ​
#  .
# ∣
# 𝑆
# ∣
# ∣S∣ is the size of the parent node's dataset (the total number of samples before the split).
#
# Entropy(S_i) is the entropy of each subset
# 𝑆
# 𝑖
# S
# i
# ​
#   (the impurity of the child nodes).
#
# The summation
# ∑
# 𝑖
# =
# 1
# 𝑛
# ∑
# i=1
# n
# ​
#   considers all subsets (or child nodes) created after the split.
#
# Steps for Calculating Information Gain:
#
# Calculate the entropy of the parent node: This is the entropy of the dataset before the split, which measures how impure the data is at that point.
# Calculate the entropy for each subset: After splitting the dataset on a feature, calculate the entropy for each of the resulting subsets (child nodes).
# Calculate the weighted sum of the child entropies: Multiply each subset's entropy by the proportion of samples in that subset relative to the total dataset.
#
# Compute the Information Gain: Subtract the weighted sum of the child entropies from the parent entropy. The higher the Information Gain, the better the feature for splitting the data.
#
# How Information Gain is Used in Decision Trees:
# Feature Selection: At each step of growing the tree, the decision tree algorithm considers all possible features to split on. The algorithm calculates the Information Gain for each feature and selects the one that gives the highest Information Gain (i.e., the feature that reduces entropy the most).
#
# Goal: The idea is to reduce uncertainty or disorder at each split. Features that provide the highest reduction in entropy will result in more "pure" child nodes, leading to better classification or prediction.
#
# Example:
#
# Let's say we have a dataset where we're trying to classify whether a customer buys a product based on two features: Age and Income. We need to calculate the Information Gain for each feature.
#
# Parent Entropy:
#
# Suppose the dataset has 60% "Yes" (buys the product) and 40% "No" (does not buy the product).
# The entropy of the parent node is calculated based on this distribution.
#
# Entropy after Split:
#
# For the Age feature, we divide the data into two groups: Young and Old. Each group has a certain proportion of "Yes" and "No". We calculate the entropy for each of these subsets (Young and Old).
# Similarly, we split the data by Income into two groups: High Income and Low Income, and calculate the entropy for each subset.
#
# Calculate Information Gain:
#
# Subtract the weighted average of the child node entropies from the parent entropy to find the Information Gain for both the Age and Income features.
# The feature with the highest Information Gain will be chosen for the next split.

# %% [markdown]
# **Question No6:** What is the difference between Gini Impurity and Entropy
#
# **Answer:**
#
# The difference between Gini Impurity and Entropy lies mainly in the way they measure the "impurity" or "disorder" of a node in a Decision Tree. Both are used to guide the algorithm in choosing the best feature to split on, but they have subtle differences in how they calculate and interpret impurity. Here's a breakdown:
#
# 1. Formula Difference:
#
# Gini Impurity:
#
# 𝐺
# 𝑖
# 𝑛
# 𝑖
# =
# 1
# −
# ∑
# 𝑖
# =
# 1
# 𝐶
# 𝑝
# 𝑖
# 2
# Gini=1−
# i=1
# ∑
# C
# ​
#  p
# i
# 2
# ​
#
# Where
# 𝑝
# 𝑖
# p
# i
# ​
#   is the proportion of class
# 𝑖
# i in the dataset at that node.
#
# Entropy:
#
# 𝐸
# 𝑛
# 𝑡
# 𝑟
# 𝑜
# 𝑝
# 𝑦
# =
# −
# ∑
# 𝑖
# =
# 1
# 𝐶
# 𝑝
# 𝑖
# log
# ⁡
# 2
# (
# 𝑝
# 𝑖
# )
# Entropy=−
# i=1
# ∑
# C
# ​
#  p
# i
# ​
#  log
# 2
# ​
#  (p
# i
# ​
#  )
# Where
# 𝑝
# 𝑖
# p
# i
# ​
#   is the proportion of class
# 𝑖
# i in the dataset at that node.
#
# 2. Interpretation:
#
# Gini Impurity measures the likelihood that a randomly chosen element from the dataset will be misclassified if it is randomly labeled according to the class distribution at that node.
#
# Range: Gini impurity ranges from 0 (pure node, all samples are from one class) to 1 (completely impure, classes are mixed equally).
# Entropy measures the level of uncertainty or disorder in the data at a node. It is based on the concept of information theory and represents the amount of "information" needed to classify an element correctly.
#
# Range: Entropy also ranges from 0 (pure node) to
# log
# ⁡
# 2
# (
# 𝐶
# )
# log
# 2
# ​
#  (C) (completely impure, where C is the number of classes and each class is equally represented).
#
# 3. Sensitivity to Distribution:
#
# Gini Impurity:
#
# Gini tends to favor larger classes over smaller classes, and it is generally faster to compute than entropy.
# Gini Impurity is typically less sensitive to small changes in the class distribution.
# For example, in a binary classification with 50% class A and 50% class B, the Gini impurity is 0.5. If we change the distribution slightly, say 51% and 49%, the Gini impurity will still be close to 0.5.
# Entropy:
#
# Entropy is more sensitive to changes in the distribution, especially when classes are not balanced.
# For example, if a node has a 50-50 split between two classes, its entropy will be 1, but if the split becomes 51-49, the entropy will decrease more noticeably.
#
# 4. Calculation of Impurity:
#
# Gini Impurity: Tends to produce shallower trees because it focuses more on reducing the majority class, making it more "greedy."
# Entropy: Can result in deeper trees, since it is more "cautious" in terms of selecting splits that bring greater overall information gain.
#
# 5. Preferred Use:
#
# Gini Impurity: Often used in Random Forests and is a bit more popular because of its computational efficiency and simpler interpretation.
# Entropy: Typically used when the goal is to maximize information gain and minimize uncertainty, and it is more commonly used in algorithms like ID3.
#
# 6. Computational Efficiency:
#
# Gini Impurity is faster to compute since it does not require logarithmic calculations like entropy does.
# Entropy requires the calculation of
# 𝑝
# 𝑖
# log
# ⁡
# 2
# (
# 𝑝
# 𝑖
# )
# p
# i
# ​
#  log
# 2
# ​
#  (p
# i
# ​
#  ), which makes it slightly slower in terms of computation compared to Gini Impurity.
#
# 7. Behavior in Practice:
#
# Gini Impurity and Entropy often lead to very similar decision trees. However, Gini Impurity typically results in slightly simpler trees, while Entropy may lead to slightly more complex trees because it is more "careful" about making splits.
#
# In general, Gini Impurity is a bit more efficient computationally, while Entropy may result in slightly better performance in terms of classification, especially for small datasets where information gain can make a noticeable difference.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question No7:** What is the mathematical explanation behind Decision Trees
#
# **Answer:**
#
# Mathematical Explanation Behind Decision Trees
#
# A Decision Tree is a supervised learning algorithm used for classification and regression tasks. It splits the dataset recursively into subsets, each of which is more homogeneous or "pure" with respect to the target variable. The key mathematical idea behind decision trees involves splitting the data in a way that minimizes some measure of impurity (such as Gini Impurity or Entropy) or maximizes a measure of information gain.
#
# 1. Basic Structure of a Decision Tree:
#
# A Decision Tree consists of:
#
# Nodes: Represent tests or decisions based on features.
# Root node: The topmost node, representing the entire dataset.
# Internal nodes: Nodes that represent tests or splits on features.
# Leaf nodes: Final decision points, where the prediction is made.
# Edges: Arrows that represent the outcome of a test, leading to child nodes.
# The goal is to create a tree that classifies or predicts values based on the input features, making decisions by branching according to the conditions on features.
#
# 2. Splitting the Data:
#
# At each node, the dataset is split based on a feature that best separates the data. The decision of how to split is based on mathematical measures of impurity.
#
# 3. Impurity Measures (Mathematical Formulation):
#
# At each node, we compute an impurity measure (Gini Impurity or Entropy) to evaluate the "impurity" or "disorder" of the data in that node. The objective is to minimize the impurity in child nodes after a split, as this will result in more "pure" subsets.
#
# Gini Impurity:
#
# For a node with
#
# C classes, the Gini Impurity is defined as:
#
# Gini=1−
# i=1
# ∑
# C
# ​
#  p
# i
# 2
# ​
#
# Where:
#
# p i is the proportion of instances of class i in the node.
#
# C is the number of classes in the target variable.
#
# Entropy:
# Entropy is another measure of impurity. It is defined as:
#
# Entropy=−
# i=1
# ∑
# C
# ​
#  p
# i
# ​
#  log
# 2
# ​
#  (p
# i
# ​
#  )
#
# Where:
#
# 𝑝
# 𝑖
# p
# i
# ​
#   is the proportion of instances of class
# 𝑖
# i in the node.
# 𝐶
# C is the number of classes in the target variable.
#
# 4. Information Gain (IG):
#
# Information Gain is used in the decision tree algorithm to evaluate the usefulness of a feature for splitting the data. The goal is to split the data in a way that reduces uncertainty or impurity.
#
# Information Gain Formula:
#
# Information Gain is calculated by measuring the reduction in entropy after a split. It is defined as:
#
# IG=Entropy(Parent)−
# i=1
# ∑
# n
# ​
#
# ∣S∣
# ∣S
# i
# ​
#  ∣
# ​
#  ×Entropy(S
# i
# ​
#  )
#
# Where:
#
# Parent
# Parent is the entropy of the current node (before the split).
#
# S
# i
#   represents the subsets of the data resulting from the split.
#
# ∣S
# i
# ​
#  ∣ is the number of samples in subset
# 𝑆
# 𝑖
# S
# i
# ​
#  .
# ∣
# 𝑆
# ∣
# ∣S∣ is the total number of samples in the parent node.
# Entropy
# (
# 𝑆
# 𝑖
# )
# Entropy(S
# i
# ​
#  ) is the entropy of each subset
# 𝑆
# 𝑖
# S
# i
# ​
#   after the split.
# The goal is to choose the feature that maximizes Information Gain (i.e., the one that reduces entropy the most). A higher Information Gain indicates a more informative feature.
#
# 5. Selecting the Best Feature to Split:
#
# To decide how to split the data at each node, we compute the impurity measure for each possible feature and split, and select the one that leads to the largest reduction in impurity (i.e., maximum Information Gain).
#
# Mathematically, the process looks like this:
#
# For each feature, we consider all possible split points.
# For each split, calculate the impurity (Gini or Entropy) for the resulting child nodes.
# Calculate the Information Gain (or impurity reduction) for each split.
# Choose the split with the highest Information Gain.
#
# 6. Recursive Splitting:
#
# Once the best feature and split are found at a node, the dataset is divided into two subsets, and the process repeats recursively for each child node. This recursion continues until one of the stopping criteria is met, such as:
#
# The node is pure (i.e., all samples belong to the same class).
# The node contains fewer than a minimum number of samples.
# The tree has reached a maximum depth.
#
# 7. Stopping Criteria:
#
# Maximum Depth: Stop splitting if the tree reaches a certain depth.
# Minimum Samples per Node: Stop splitting if a node has fewer than a certain number of samples.
# Pure Node: If all data points in a node belong to a single class, the recursion stops.
# Maximum Information Gain: If further splits do not result in meaningful reductions in impurity, the recursion stops.
#
# 8. Mathematical Representation of a Decision Tree's Growth:
#
# Let’s consider a set of
# 𝑁
# N training samples
# 𝑋
# =
# {
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑁
# }
# X={x
# 1
# ​
#  ,x
# 2
# ​
#  ,…,x
# N
# ​
#  } with target labels
# 𝑌
# =
# {
# 𝑦
# 1
# ,
# 𝑦
# 2
# ,
# …
# ,
# 𝑦
# 𝑁
# }
# Y={y
# 1
# ​
#  ,y
# 2
# ​
#  ,…,y
# N
# ​
#  }. At each node, the decision tree algorithm chooses the feature
# 𝑓
# f and threshold
# 𝑡
# t to split the data based on the impurity measure (Gini or Entropy).
#
# Split the data into two subsets:
#
# 𝑋
# 𝐿
# =
# {
# 𝑥
# 𝑖
# ∣
# 𝑓
# (
# 𝑥
# 𝑖
# )
# ≤
# 𝑡
# }
# X
# L
# ​
#  ={x
# i
# ​
#  ∣f(x
# i
# ​
#  )≤t} (left child)
# 𝑋
# 𝑅
# =
# {
# 𝑥
# 𝑖
# ∣
# 𝑓
# (
# 𝑥
# 𝑖
# )
# >
# 𝑡
# }
# X
# R
# ​
#  ={x
# i
# ​
#  ∣f(x
# i
# ​
#  )>t} (right child)
# Calculate the impurity for both child nodes:
#
# 𝐺
# 𝑖
# 𝑛
# 𝑖
# 𝐿
# Gini
# L
# ​
#  ,
# 𝐺
# 𝑖
# 𝑛
# 𝑖
# 𝑅
# Gini
# R
# ​
#  , or
# 𝐸
# 𝑛
# 𝑡
# 𝑟
# 𝑜
# 𝑝
# 𝑦
# 𝐿
# Entropy
# L
# ​
#  ,
# 𝐸
# 𝑛
# 𝑡
# 𝑟
# 𝑜
# 𝑝
# 𝑦
# 𝑅
# Entropy
# R
# ​
#  .
# Compute Information Gain (for Gini Impurity or Entropy) at each split:
#
# 𝐼
# 𝐺
# =
# 𝐼
# 𝑚
# 𝑝
# 𝑢
# 𝑟
# 𝑖
# 𝑡
# 𝑦
# (
# Parent
# )
# −
# (
# ∣
# 𝑋
# 𝐿
# ∣
# ∣
# 𝑋
# ∣
# ×
# 𝐼
# 𝑚
# 𝑝
# 𝑢
# 𝑟
# 𝑖
# 𝑡
# 𝑦
# (
# Left
# )
# +
# ∣
# 𝑋
# 𝑅
# ∣
# ∣
# 𝑋
# ∣
# ×
# 𝐼
# 𝑚
# 𝑝
# 𝑢
# 𝑟
# 𝑖
# 𝑡
# 𝑦
# (
# Right
# )
# )
# IG=Impurity(Parent)−(
# ∣X∣
# ∣X
# L
# ​
#  ∣
# ​
#  ×Impurity(Left)+
# ∣X∣
# ∣X
# R
# ​
#  ∣
# ​
#  ×Impurity(Right))
# Choose the feature and split that maximizes Information Gain or minimizes impurity.
#
# 9. Regression Trees (for continuous output):
#
# In the case of regression trees, where the target is a continuous value rather than a discrete class, the impurity measure changes from Gini or Entropy to Variance. The goal is to minimize the variance in the child nodes after the split.
#
# Variance(S)=
# ∣S∣
# 1
# ​
#
# i=1
# ∑
# ∣S∣
# ​
#  (y
# i
# ​
#  −
# y
# ˉ
# ​
#  )
# 2
#
# Where:
#
# y
# i is the target value for sample
#
# i,
# ˉ
# y is the mean target value of the samples in S.
#
# The splitting criterion is to select the feature that minimizes the variance in the child nodes.

# %% [markdown]
# **Question No8:** What is Pre-Pruning in Decision Trees
#
# **Answer:**
#
# Pre-Pruning (also known as Early Stopping) in Decision Trees
# Pre-pruning is a technique used in decision tree construction to prevent overfitting by stopping the growth of the tree at an early stage, before it becomes too complex. In other words, pre-pruning aims to limit the size of the tree during its construction, preventing it from growing too deep and overfitting the training data.
#
# How Pre-Pruning Works:
#
# During the construction of a decision tree, at each node, the algorithm evaluates whether further splitting of the data will improve the model's performance. Pre-pruning introduces criteria that halt further splitting if the benefits of a split are deemed insufficient. This can be based on various stopping conditions.
#
# Key Stopping Criteria for Pre-Pruning:
#
# Maximum Depth:
#
# The tree will stop growing if it reaches a pre-specified maximum depth.
# Maximum Depth restricts how deep the tree can grow. Deeper trees are more likely to overfit, capturing noise in the data.
#
# Minimum Samples per Leaf:
#
# The algorithm stops splitting if a node would end up with fewer than a specified number of samples.
# This ensures that no node is too "pure" (with very few samples), reducing the chance of overfitting to outliers or noise.
#
# Minimum Samples per Split:
#
# A node is not split if it has fewer than a specified minimum number of samples.
# If a node has too few samples, further splitting may not be meaningful, and a decision should be made based on the majority class or mean value (for regression).
#
# Maximum Number of Leaf Nodes:
#
# The tree construction is halted if it reaches a specified maximum number of leaf nodes.
# Limiting the number of leaf nodes controls the model’s complexity.
#
# Minimum Impurity Decrease (or Minimum Information Gain):
#
# The tree will stop splitting if the reduction in impurity (e.g., Gini Impurity or Entropy) from the parent node to the child nodes is less than a specified threshold.
# This criterion ensures that splits are meaningful and improve the predictive power of the model.
#
# Maximum Features (Max Features):
#
# In some implementations (like Random Forests), the algorithm can stop splitting if a fixed subset of features has been used.
# This reduces the complexity of the tree and helps in avoiding overfitting.
#
# Benefits of Pre-Pruning:
#
# Prevents Overfitting: By restricting tree growth, it helps avoid overfitting the model to noise or small variations in the training data.
#
# Improved Generalization: A simpler tree tends to generalize better to unseen data because it is not overly complex and focused on the training data's specific nuances.
#
# Efficiency: Smaller trees are computationally more efficient to train and predict.
#
# Interpretability: Simpler trees are easier to interpret and understand.
#
# Drawbacks of Pre-Pruning:
#
# Underfitting: If the stopping criteria are too strict, the tree may be overly simplified, and thus may not capture important patterns in the data, leading to underfitting.
#
# Suboptimal Tree: Pre-pruning can lead to a suboptimal tree if the stopping conditions are not carefully tuned. It may stop splitting too early, preventing the model from finding the best splits that would lead to better predictive power.
#
# Example of Pre-Pruning in Action:
# Suppose you're building a decision tree to classify whether a person will buy a product based on features like age, income, etc. You apply
#
# pre-pruning with the following conditions:
#
# Maximum Depth = 3 (The tree can have at most 3 levels of nodes).
# Minimum Samples per Leaf = 10 (A node must have at least 10 samples before splitting).
#
# Minimum Impurity Decrease = 0.01 (A split must result in at least a 1% reduction in impurity).
#
# As the tree grows, these conditions will prevent further splits if they are violated:
#
# If a node has fewer than 10 samples, it will not be split.
# If a split doesn’t reduce the impurity by at least 1%, it will not occur.
# If the tree reaches 3 levels, no further splitting is allowed.
#
# Comparison: Pre-Pruning vs Post-Pruning
# Pre-Pruning: Stops the tree from growing too complex by limiting it during its construction.
# Post-Pruning (also called Cost Complexity Pruning or Weakest Branch Pruning): After the tree is fully grown, it starts trimming branches (subtrees) that have little to no effect on the final prediction, typically by measuring the tree’s performance on a validation set.
# While pre-pruning stops the tree early, post-pruning allows the tree to grow fully and then simplifies it, which may sometimes yield a better-performing tree (as it can capture more complex patterns before pruning out irrelevant parts).

# %% [markdown]
# **Question No9:** What is Post-Pruning in Decision Trees
#
# **Answer:**
#
# Post-Pruning (also known as Cost Complexity Pruning or Weakest Branch Pruning) in Decision Trees
# Post-pruning is a technique used in decision tree construction to remove branches that have little or no predictive power after the tree has been fully grown. The goal is to simplify the tree by pruning (cutting off) parts of it that don't contribute meaningfully to its performance, thereby improving generalization and reducing overfitting.
#
# Unlike pre-pruning, where the tree is restricted during the growth process, post-pruning occurs after the tree has been fully grown. Once the tree is built, it is evaluated, and unimportant branches (subtrees) are pruned away based on certain criteria.
#
# How Post-Pruning Works:
#
# Post-pruning generally involves the following steps:
#
# Build the Full Tree:
#
# First, a decision tree is constructed without any restrictions on depth or other parameters. This tree tends to overfit the training data, being highly complex with many nodes and branches.
#
# Evaluate the Tree's Performance:
#
# The fully grown tree is then evaluated using a validation set (or a cross-validation technique). The goal is to determine how well the tree generalizes to unseen data.
#
# Prune Weak Branches:
#
# The algorithm removes branches that do not contribute significantly to the tree’s predictive power. This is done by examining the cost-complexity of the tree, which balances the tree's complexity (size) and its accuracy.
#
# Prune Using a Cost-Complexity Measure:
#
# In post-pruning, a cost-complexity measure is used to balance the tree's complexity and its accuracy. One common method is the Cost Complexity Pruning algorithm (also called weakest branch pruning or α-pruning), which introduces a penalty term for the number of leaf nodes in the tree. This results in the removal of branches that do not significantly improve accuracy.
#
# Cost-Complexity Pruning (α-Pruning):
# The idea behind cost-complexity pruning is to find the optimal balance between tree size (complexity) and accuracy. This is achieved by using a pruning parameter α (alpha), which controls the trade-off between complexity and accuracy.
#
# The cost-complexity measure can be formulated as:
#
# (T)=R(T)+α⋅∣T∣
#
# Where:
#
# R(T) is the empirical risk (or error) of tree
#
# T, typically measured using the classification error or variance for regression tasks.
# ∣T∣ is the number of terminal nodes (leaf nodes) in tree  T.
#
# α is a penalty parameter that controls the trade-off between complexity and accuracy.
#
# Pruning Process:
# Compute the cost-complexity measure for the tree: For every subtree (starting from the leaves), calculate the error and complexity (leaf nodes) and determine the cost-complexity for each.
#
# Prune subtrees based on cost-complexity: Starting from the leaves, remove the subtrees whose cost-complexity (error + penalty) is above a certain threshold
#
# α. This is done recursively, and the pruning continues until the tree reaches an optimal size that minimizes the overall error.
#
# Determine the optimal value of α: The parameter
#
# α controls how much pruning should be done. By testing different values of
#
# α, the optimal tree size can be determined — typically by using cross-validation to select the value of
#
# α that gives the best performance.
#
# Re-evaluate after pruning: After pruning, the tree is re-evaluated using the validation set to ensure it still performs well. The final tree structure represents the most simplified version of the model that maintains a good balance between accuracy and complexity.
#
# Benefits of Post-Pruning:
# Reduces Overfitting: After a decision tree is fully grown, it is often overly complex and overfits the training data. Post-pruning helps to reduce overfitting by simplifying the tree and removing parts that don't generalize well to unseen data.
#
# Improves Generalization: By removing unnecessary branches, post-pruning creates a model that better generalizes to new, unseen data.
#
# More Compact Tree: Post-pruned trees are typically smaller and more interpretable, making them easier to understand and analyze.
#
# Flexibility: Unlike pre-pruning, where the tree is constrained during construction, post-pruning allows the tree to grow fully and then removes unnecessary parts, which can often result in a better-performing model.
#
# Drawbacks of Post-Pruning:
# Computationally Expensive: Post-pruning involves growing the entire tree first, which may be computationally expensive, especially for large datasets.
#
# Requires Validation Set: Post-pruning relies on a validation set or cross-validation to evaluate the effectiveness of pruning, which may not always be available or might increase the need for computational resources.
#
# Risk of Underpruning: There’s a risk that post-pruning may not prune enough branches, leaving parts of the tree that still contribute to overfitting.
#
# Example of Post-Pruning:
# Let’s say you have a decision tree that was fully grown on a dataset for a classification problem. The tree has 15 leaves and looks very complex. Using cost-complexity pruning, the following steps would happen:
#
# Step 1: Compute the error and cost-complexity of each subtree, including its number of leaf nodes and the empirical risk.
# Step 2: Begin pruning the least valuable branches (those with minimal impact on accuracy) by cutting them off.
# Step 3: Continue pruning iteratively, using cross-validation to find the optimal balance (i.e., the value of
# 𝛼
# α).
# Step 4: The final pruned tree, which may have only 8 leaves, is now smaller and should generalize better.

# %% [markdown]
# **Question No10:** What is the difference between Pre-Pruning and Post-Pruning
#
# **Answer:**
#
# 1. Timing of Pruning
#
# Pre-Pruning (Early Stopping):
#
# Pre-pruning occurs during the tree-building process. The decision tree is restricted at each node before it fully grows.
# The algorithm halts tree growth early based on predefined criteria, such as maximum depth, minimum samples per leaf, or minimum impurity decrease.
#
# Post-Pruning (Cost Complexity Pruning):
#
# Post-pruning occurs after the tree has been fully grown. First, the tree is allowed to grow fully (possibly overfitting the training data), and then pruning takes place to remove unimportant branches.
# The tree is pruned based on an evaluation of the tree's performance (typically on a validation set) to remove parts that do not improve the generalization.
#
# 2. Approach to Tree Growth
#
# Pre-Pruning:
#
# The tree is "pruned" during its growth. The splitting stops early when certain conditions are met (e.g., reaching a maximum depth or too few samples in a node).
# This prevents the tree from becoming too complex in the first place.
#
# Post-Pruning:
#
# The tree grows fully (with no restrictions) and becomes as complex as possible.
# After the tree is built, branches or subtrees are removed (pruned) if they do not significantly improve predictive performance.
#
# 3. Control Over Complexity
#
# Pre-Pruning:
#
# Complexity is controlled during the tree construction. The tree is "restricted" in its growth through pre-defined stopping criteria (e.g., maximum depth, minimum samples per leaf).
# This ensures that the tree does not become too large and overfit the training data.
#
# Post-Pruning:
#
# Complexity is controlled after the tree is built. Post-pruning allows for a fully-grown tree and later simplifies it by removing weak or unnecessary branches.
# This method typically results in a more accurate tree since it allows the tree to grow and capture useful patterns before deciding what to prune.
#
# 4. Stopping Criteria
#
# Pre-Pruning:
#
# Pre-defined stopping rules such as:
# Maximum tree depth.
# Minimum number of samples per node.
# Minimum information gain or impurity decrease.
#
# Post-Pruning:
#
# Cost-complexity pruning (α-pruning) or other post-hoc measures:
# After the tree is fully grown, subtrees are pruned based on their contribution to accuracy, often evaluated on a validation set.
# A pruning parameter (α) helps control the trade-off between accuracy and complexity.
#
# 5. Risk of Overfitting and Underfitting
#
# Pre-Pruning:
#
# Risk of Underfitting: Since the tree is restricted early on, there’s a risk that important patterns in the data will not be captured (i.e., the tree is too simple).
# It might stop splitting prematurely, resulting in lower accuracy if the stopping criteria are too strict.
#
# Post-Pruning:
#
# Risk of Overfitting: The tree is allowed to grow fully, which increases the risk of overfitting, especially if the tree is too deep or complex.
# However, post-pruning can mitigate overfitting after the tree is grown by removing irrelevant branches.
#
# 6. Computational Efficiency
#
# Pre-Pruning:
#
# More efficient during training since the tree is pruned early, meaning less computation is needed for splitting nodes and growing the tree.
# The algorithm stops splitting when the stopping criteria are met, saving time.
#
# Post-Pruning:
#
# Less efficient since it requires building the entire tree first and then pruning. This increases the computational time and resource usage.
# The pruning process involves evaluating the tree’s performance and may involve more computational overhead.
#
# 7. Interpretability
#
# Pre-Pruning:
#
# The resulting tree is typically simpler and more interpretable since its growth was restricted from the beginning.
# Fewer branches and nodes make it easier to understand and explain.
#
# Post-Pruning:
#
# The resulting tree may be more complex initially but is simplified after pruning.
# Post-pruned trees are often more accurate but may still be harder to interpret than pre-pruned trees, especially if complex branches are pruned late in the process.
#
# 8. Example of When Each is Used
#
# Pre-Pruning:
#
# Often used when computational efficiency is important, and overfitting must be controlled from the start. It’s a good choice when we have limited training data and want to avoid overly complex models early on.
# Example: Using pre-pruning with a constraint of maximum depth = 5 or minimum samples per leaf = 10 in cases where a simple model is desired.
#
# Post-Pruning:
#
# Used when accuracy is the primary goal, and we are willing to build a more complex model initially. After the tree grows fully, post-pruning helps fine-tune the tree by removing unnecessary complexity.
# Example: Building a fully grown tree and then pruning it to reduce overfitting, especially when we have enough data and can afford some extra computational effort.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question No11:** What is a Decision Tree Regressor
#
# **Answer:**
#
# Decision Tree Regressor:
#
# A Decision Tree Regressor is a type of decision tree algorithm used for regression tasks, where the goal is to predict a continuous output variable (e.g., a numerical value) based on input features. It is a supervised learning model, meaning it requires labeled data (input-output pairs) for training.
#
# The decision tree works by recursively splitting the data into subsets based on feature values, with the objective of making predictions that minimize error (e.g., Mean Squared Error) for the output variable. In the case of regression, instead of classifying data into categories (as in classification tasks), the tree predicts numerical values.
#
# How a Decision Tree Regressor Works:
#
# Split the Data:
#
# The algorithm starts by splitting the data based on the values of the features to create "branches."
# At each node, the algorithm selects a feature and its threshold (cut-off value) that best splits the data into two groups, with the goal of reducing the variance in the target variable.
#
# Create Child Nodes:
#
# This splitting process continues recursively, where each node splits based on the feature that minimizes the variance of the target variable in the child nodes.
#
# Stopping Criteria:
#
# The process continues until a stopping criterion is met, such as:
# Reaching a maximum depth of the tree.
# The data within the node cannot be split further (e.g., all target values are the same).
# A node has fewer than a minimum number of samples.
# The reduction in variance after a split is below a threshold.
#
# Prediction at Leaf Nodes:
#
# Once the tree reaches the leaf nodes, the prediction is made by taking the average value of the target variable for the samples in that leaf.
# The prediction for a given input is obtained by tracing the path down the tree based on the input features until reaching a leaf node, where the average value of the target variable in that node is the predicted output.
#
# Key Concepts in Decision Tree Regressor:
#
# Splitting Criterion (Variance Reduction):
#
# For regression, decision trees typically use metrics like variance to determine the best split. The goal is to split the data such that the variance of the target variable in each child node is minimized.
# A common splitting criterion is Mean Squared Error (MSE) or Variance Reduction. The split that reduces the most variance in the target variable will be chosen.
#
# The variance of a set of values is calculated as:
#
# Variance=
# N
# 1
# ​
#
# i=1
# ∑
# N
# ​
#  (y
# i
# ​
#  −
# y
# ˉ
# ​
#  )
# 2
#
# Where:
#
# 𝑦
# 𝑖
# y
# i
# ​
#   are the individual target values (e.g., house prices, sales amounts).
# 𝑦
# ˉ
# y
# ˉ
# ​
#   is the mean of those target values.
# N is the number of data points.
# The algorithm aims to minimize the variance in each subset formed by the split.
#
#
# Prediction:
#
# For a regression problem, the output at the leaf node is typically the mean of the target values of the samples that reach that leaf. So, the prediction at a leaf node is the average target value of the data points within that leaf.
#
# Advantages of Decision Tree Regressor:
#
# Easy to Understand and Interpret:
#
# Decision trees are very intuitive. You can visualize the tree and understand how decisions (predictions) are being made, making it easy to explain to non-technical stakeholders.
#
# Handles Non-linearity:
#
# Decision trees can capture non-linear relationships between the input features and the target variable, which can be an advantage over linear models like linear regression.
#
# No Need for Feature Scaling:
#
# Unlike other algorithms such as Support Vector Machines or k-Nearest Neighbors, decision trees do not require feature scaling (e.g., normalization or standardization) because they are based on splitting values based on thresholds.
#
# Handles Mixed Data Types:
#
# Decision trees can handle both numerical and categorical data, which makes them versatile for various types of datasets.
#
# Disadvantages of Decision Tree Regressor:
#
# Overfitting:
#
# Decision trees can easily overfit the data, especially if they grow too deep. Overfitting happens when the model learns the noise or details of the training data that do not generalize well to unseen data.
# Pre-pruning or post-pruning is often used to reduce overfitting, but the model's performance can still degrade if not carefully tuned.
#
# Instability:
#
# Decision trees can be unstable in the sense that small changes in the data can lead to completely different tree structures. This is particularly problematic with high variance in the dataset.
#
# Bias towards Features with More Levels:
#
# Decision trees can be biased towards features that have more distinct values or categories, especially if the tree grows too deep. This bias can lead to less optimal models if not properly regularized.
#
# Limited Performance with Complex Data:
#
# While decision trees can capture non-linearity, they may still struggle with very complex relationships in the data. Ensemble methods like Random Forests or Gradient Boosting Trees can often perform better for such cases.

# %% [markdown]
# **Question No12:** What are the advantages and disadvantages of Decision Trees
#
# **Answer:**
#
# Advantages of Decision Trees:
#
# Easy to Understand and Interpret:
#
# Decision trees are simple to understand and visualize. The tree structure mimics human decision-making, so the logic behind the model can be easily explained to non-technical stakeholders.
# The decisions made at each node are clear, making it easy to trace how a particular prediction was made.
#
# Handles Both Numerical and Categorical Data:
#
# Decision trees can handle both numerical and categorical data without the need for additional preprocessing steps like one-hot encoding (for categorical variables) or normalization/standardization (for numerical data).
#
# Non-linearity:
#
# Decision trees can model complex, non-linear relationships in data. Unlike linear models (e.g., linear regression), decision trees do not assume a linear relationship between the features and the target variable.
#
# No Feature Scaling Required:
#
# Unlike algorithms such as Support Vector Machines (SVM) or k-Nearest Neighbors (k-NN), decision trees do not require feature scaling (e.g., normalization or standardization of features). The tree is built based on splitting the data at different thresholds, which is not affected by the scale of the features.
#
# Feature Importance:
#
# Decision trees inherently provide a way to assess the importance of different features in making predictions. The splitting criterion (e.g., Gini impurity or Information Gain) directly tells us how important each feature is in the model.
#
# Versatile:
#
# Decision trees can be used for both classification and regression tasks, making them a versatile tool for various types of predictive modeling problems.
#
# Handles Missing Data:
#
# Some implementations of decision trees, like the one in scikit-learn, can handle missing data by automatically finding the best split even when some data points are missing certain feature values.
#
# Disadvantages of Decision Trees:
#
# Prone to Overfitting:
#
# Overfitting is a major issue with decision trees, especially if the tree is allowed to grow too deep. The model may capture too much noise or small variations in the training data, which leads to poor generalization to unseen data.
# This can be mitigated through techniques like pruning, limiting the depth of the tree, or using ensemble methods like Random Forests or Gradient Boosting Machines.
#
# Instability:
#
# Decision trees can be very sensitive to small changes in the data. A small variation in the dataset can lead to a completely different tree structure. This lack of stability is a problem, especially when working with high-variance data.
# This instability can also make decision trees less reliable when the training data is noisy.
#
# Bias Towards Features with More Categories:
#
# Decision trees tend to favor features with more distinct values or categories. For instance, if a feature has many unique values, it may be selected more often during the splitting process, even if that feature is not genuinely important.
# This bias can result in suboptimal trees if not handled appropriately, particularly when dealing with categorical features.
#
# Greedy Nature (Local Optima):
#
# The decision tree algorithm is greedy, meaning it makes the best decision at each step based on local information (e.g., the best split at each node). However, this might not lead to the globally optimal tree structure.
# The algorithm doesn't look ahead or consider the consequences of decisions down the tree, which could lead to suboptimal splits.
#
# Poor Performance on Unstructured Data:
#
# Decision trees do not perform well on certain types of unstructured data, like images, text, or sequences, where more specialized models like convolutional neural networks (CNNs) or recurrent neural networks (RNNs) would be more appropriate.
#
# Can Be Complex and Difficult to Interpret for Deep Trees:
#
# While small trees are interpretable, very deep trees can become very complex and difficult to understand. Large trees can lose the advantage of simplicity and interpretability.
#
# May Struggle with Interactions Between Features:
#
# Decision trees do not capture interactions between features well unless the interaction is explicitly encoded in the data. This limitation can lead to suboptimal performance if the relationship between features is highly interactive and complex.
#
# Exponential Growth in Time and Space with Depth:
#
# As the depth of the tree increases, the computational complexity also increases, especially when dealing with a large number of features and data points. Very deep trees can result in long training times and increased memory usage.
#
# Ways to Overcome the Disadvantages:
#
# Pruning: To combat overfitting, decision trees can be pruned either during or after tree construction (pre-pruning or post-pruning). This helps to keep the tree from becoming too complex.
#
# Ensemble Methods:
#
# Random Forests and Gradient Boosting Machines (GBM) are ensemble methods that combine multiple decision trees to reduce overfitting and improve model stability. These methods also help with the instability issue by averaging predictions or using boosting techniques.
#
# Limiting Depth: Setting a maximum depth or a minimum number of samples required to split nodes can prevent overfitting by forcing the tree to stay simpler.
#
# Cross-validation: Using cross-validation during model training can help assess the model’s generalization and prevent overfitting by tuning hyperparameters (e.g., max depth, min samples per leaf).

# %% [markdown]
# **Question No13:** How does a Decision Tree handle missing values
#
# **Answer:**
#
# Handling Missing Values in Decision Trees
#
# In decision trees, handling missing values effectively is important because real-world data often contains missing or incomplete information. Different decision tree implementations may handle missing values in different ways, but there are a few common strategies used to deal with missing data during both the training phase and the prediction phase.
#
# Here are the main techniques that decision trees use to handle missing values:
#
# 1. Ignoring the Missing Value (Dropping Samples)
#
# Training Phase:
#
# One simple approach is to ignore the samples with missing values. This means that during training, if a feature value is missing for a particular sample, that sample is excluded from any split or decision-making process.
#
# Pros: Easy to implement and computationally efficient.
#
# Cons: This can result in losing valuable data, especially if many features have missing values, leading to biased models or poor generalization.
# Prediction Phase:
#
# When making predictions, if a sample contains missing values, the algorithm can ignore it during tree traversal. In some cases, this could involve simply skipping the node where the feature is missing.
#
# 2. Surrogate Splits (Backup Splits)
#
# Training Phase:
#
# A more sophisticated method is to use surrogate splits. If a decision tree encounters a missing value at a particular node, it doesn't need to skip the sample. Instead, it uses a backup or surrogate split based on a different feature that is most correlated with the original split feature.
#
# How it works: If the primary feature for splitting the data has missing values, the decision tree looks for another feature that can "back up" or mimic the decision of the primary feature. The surrogate split is based on the feature that produces the most similar result in the training data.
#
# Pros: Keeps more samples in the training process, improving the model's accuracy.
#
# Cons: Requires additional computation to identify the surrogate splits, and the surrogate might not always be as effective as the original split.
#
# Prediction Phase:
#
# During prediction, if a feature value is missing, the decision tree will use the surrogate split to decide which branch to follow. This ensures that the missing data does not prevent a prediction from being made.
#
# 3. Imputation (Replacing Missing Values)
#
# Training Phase:
#
# Another common approach is to impute missing values before the decision tree model is trained. This means filling in the missing values with some predefined value such as:
#
# Mean or median for numerical features.
# Most frequent category (mode) for categorical features.
# This method is effective when the missing data is randomly distributed, but it can introduce bias if the missing values are not missing completely at random (e.g., if data is missing due to a pattern).
#
# Pros: Simple to implement and doesn’t require altering the decision tree’s structure.
#
# Cons: Imputation may introduce bias if not handled carefully, especially if the missing values are not random or are systematically missing based on certain patterns in the data.
#
# Prediction Phase:
#
# For prediction, any missing values in the test data can be imputed using the same method applied during training (e.g., replacing missing values with the mean or mode of the training set).
#
# 4. Using Probabilistic Splits
#
# Training Phase:
# In some implementations of decision trees, when a sample with missing values reaches a node, the algorithm might use probabilistic splitting. It divides the sample based on the probability distribution of how the missing value would be classified based on the other available features.
# The algorithm looks at the values in the data and calculates the probability distribution for each feature split, considering the missing data and the distribution of values for that feature.
#
# Pros: Allows the tree to make informed decisions when data is missing, leading to more accurate models.
#
# Cons: More computationally intensive and complex to implement.
#
# 5. Using "Missing" as a Separate Category (for Categorical Features)
#
# Training Phase:
# For categorical features, the decision tree can treat missing values as a separate category or "label" and split the data accordingly.
# When building the tree, any instance with a missing value for a categorical feature will be assigned to a specific "missing" category, and the tree will build branches based on that.
#
# Pros: Useful when missing data can be a meaningful indicator by itself.
#
# Cons: This approach assumes that missing values are a distinct category, which might not always make sense depending on the context of the data.
#
# 6. Using Model-Based Approaches (e.g., Random Forests)
#
# Training Phase:
#
# In ensemble models like Random Forests, individual trees can handle missing values differently, and the ensemble can aggregate predictions from different trees. When training multiple decision trees, the individual trees can handle missing values in their own way (e.g., using surrogate splits, imputing, or ignoring missing values), and the final prediction is made based on the majority voting (for classification) or averaging (for regression) across all the trees.
#
# Pros: Using multiple trees reduces the impact of missing data on any one
# tree, leading to more robust models.
#
# Cons: Requires more computational resources as it builds multiple trees.
# Decision Tree Libraries and Missing Values
# In popular machine learning libraries such as scikit-learn, XGBoost, and LightGBM, handling missing values is often done automatically or through specific parameters:
#
# scikit-learn: Does not directly handle missing values. Missing values must be handled before training the model (e.g., imputation or removing samples).
#
# XGBoost: Handles missing values automatically by assigning them to the best possible split (effectively treating missing values as a separate "category" and using the best possible direction based on data).
#
# LightGBM: Similar to XGBoost, LightGBM automatically handles missing values by finding the best possible split direction during training.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question No14:** How does a Decision Tree handle categorical features
#
# **Answer:**
#
# Handling Categorical Features in Decision Trees
#
# In decision trees, categorical features are features that take on a limited, fixed number of possible values (often referred to as categories or levels). For example, a feature like "Color" could have the categories "Red," "Green," and "Blue," while a feature like "Day of the Week" could have values like "Monday," "Tuesday," etc.
#
# Unlike numerical features, where decision trees simply look for a threshold (e.g.,
# 𝑥
# <
# 5
# x < 5), categorical features require a different approach for making splits.
#
# Here’s how decision trees handle categorical features:
#
# 1. Binary Splits for Categorical Features (in Classification)
#
# For classification tasks, when using categorical features, decision trees typically perform binary splits based on whether the data in the feature belongs to a particular category or not.
#
# How it Works:
# When constructing the tree, the algorithm evaluates the categorical feature and tests all possible binary partitions. This means it considers splitting the data into two groups: one where the feature is equal to a particular category and one where the feature is not.
#
# For instance, if the categorical feature is "Color" with categories "Red," "Green," and "Blue," the decision tree might split the data into two groups:
#
# One group where "Color" = "Red" (e.g.,
# Color
# =
# Red
# Color=Red)
# Another group where "Color" ≠ "Red" (e.g.,
# Color
# ≠
# Red
# Color
# 
# =Red)
#
# Example:
# For a dataset with a categorical feature Color and a binary target variable (e.g., "Yes"/"No"), a potential split could look like:
#
# Split 1: Color = Red
# Split 2: Color ≠ Red (includes all non-red colors like Green, Blue, etc.)
# The tree will then evaluate which split leads to a better reduction in impurity (e.g., Gini impurity or entropy) in the target variable.
#
# Pros:
# Allows the tree to efficiently handle categorical features with multiple levels.
# Keeps the tree structure simple and interpretable.
#
# Cons:
# If a categorical feature has many categories, the number of possible binary splits increases significantly, leading to potentially large, complex trees. This can increase computation time and make the model more prone to overfitting.
#
# 2. Splitting by Grouping Categories (for Multiclass Categorical Features)
#
# For categorical features with multiple categories (e.g., "Color" with categories "Red," "Green," "Blue"), instead of splitting by individual categories, decision trees can consider grouping categories together in multi-way splits. This can be especially useful when there are too many categories in the feature.
#
# How it Works:
# The tree may group categories into sets and then decide whether a feature belongs to one of those groups or not.
# For example, if we have a "Day" feature with categories "Monday," "Tuesday," "Wednesday," "Thursday," "Friday," "Saturday," and "Sunday," the tree might split by grouping "Weekdays" (Monday–Friday) and "Weekend" (Saturday–Sunday).
# Example:
# Split 1: Day ∈ Weekdays (i.e., Monday–Friday)
# Split 2: Day ∈ Weekend (i.e., Saturday–Sunday)
#
# Pros:
# Reduces the complexity of categorical features with many categories.
# Grouping categories helps the tree focus on broader patterns rather than splitting by every individual category.
#
# Cons:
# Requires careful preprocessing or the use of domain knowledge to define appropriate groups.
# May lead to less precision if the grouping doesn't align well with the data's structure.
#
# 3. One-Hot Encoding (for Decision Trees That Require Numeric Input)
#
# Many decision tree algorithms (such as those in scikit-learn) expect input features to be numerical. For categorical features, one common method is one-hot encoding, which transforms each category into a separate binary (0 or 1) feature.
#
# How it Works:
# One-hot encoding creates a new binary feature for each category in the original categorical feature. If the feature "Color" has three categories ("Red," "Green," "Blue"), one-hot encoding will create three new binary features:
#
# IsRed (1 if the color is "Red," otherwise 0)
# IsGreen (1 if the color is "Green," otherwise 0)
# IsBlue (1 if the color is "Blue," otherwise 0)
# After one-hot encoding, each of these new features is treated as a numerical feature, and the decision tree can now use standard numeric splits.
#
# Pros:
# Decision trees can now handle categorical features using standard numeric splits.
# The interpretability of the model remains clear.
#
# Cons:
# Curse of dimensionality: If the categorical feature has many unique categories, one-hot encoding can lead to a large number of features, which can increase the complexity of the model.
# Increased memory usage: More features may also lead to higher memory consumption and slower training times.
#
# 4. Decision Trees in Libraries (e.g., Scikit-learn, XGBoost)
# Scikit-learn Decision Trees:
#
# Default Handling: In scikit-learn, decision trees don’t directly support categorical features, but they can be handled with one-hot encoding or by converting the categorical values into numerical representations (e.g., using label encoding).
# Multi-class Splits: Scikit-learn handles categorical variables by checking all potential binary splits (for each category vs. not category) and picking the one that leads to the greatest reduction in impurity.
#
# XGBoost and LightGBM:
# Native Support for Categorical Features: Both XGBoost and LightGBM have more advanced handling for categorical features and can directly process categorical variables without needing to one-hot encode them. They automatically decide the best splits based on category values and may offer more efficient models, particularly with features with many categories.
#
# Categorical Split Optimization: These libraries use more sophisticated methods to handle categorical features, such as splitting based on histograms (binned values) and using monotonic constraints to optimize the splits.
#
# 5. Label Encoding (Alternative for Ordinal Categorical Features)
#
# If a categorical feature has an ordinal relationship (i.e., categories have a meaningful order, such as "Low," "Medium," and "High"), label encoding can be used to assign a unique integer to each category (e.g., "Low" = 0, "Medium" = 1, "High" = 2).
#
# How it Works:
# The categories are mapped to integers, and decision trees can then split based on these numerical values. However, this method should only be used for ordinal features, where the order matters.
#
# Example:
# For the "Size" feature with categories "Small," "Medium," and "Large," label encoding would assign values:
#
# Small → 0
# Medium → 1
# Large → 2
#
# Pros:
# Simple to implement.
# Preserves the ordinal relationship between categories.
#
# Cons:
# This approach assumes an ordinal relationship, which may not be valid for nominal categories. For nominal features (with no inherent order), this could lead to misleading splits.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question No15:** What are some real-world applications of Decision Trees?
#
# **Answer:**
#
# Real-World Applications of Decision Trees
#
# Decision trees are versatile machine learning models that can be applied across various domains due to their interpretability, simplicity, and ability to handle both categorical and numerical data. Here are some of the most common real-world applications:
#
# 1. Healthcare and Medical Diagnosis
#
# Decision trees are widely used in healthcare to assist with medical diagnosis and treatment recommendations.
#
# Disease Diagnosis: Decision trees can be used to classify patients based on their symptoms and medical history. For example, diagnosing whether a patient has a certain disease (e.g., diabetes, heart disease, cancer) based on test results and other health indicators.
# Example: In a decision tree for diagnosing diabetes, features could include age, weight, glucose levels, family history, and blood pressure. The decision tree can then predict whether a person is likely to have diabetes or not.
# Treatment Recommendations: In treatment planning, decision trees help doctors recommend personalized treatment plans based on patient attributes.
# Example: For cancer treatment, decision trees might classify whether a patient should undergo surgery, chemotherapy, or radiation based on tumor size, location, and type.
#
# 2. Finance and Banking
#
# In the finance industry, decision trees are used to assess risk, detect fraud, and make investment decisions.
#
# Credit Scoring: Banks and financial institutions use decision trees to assess the creditworthiness of loan applicants. The decision tree can consider factors like income, credit history, employment status, and loan amount.
#
# Example: Predicting whether an individual will default on a loan based on their financial data (e.g., past loan performance, monthly income, credit score).
# Fraud Detection: Decision trees can be used to detect fraudulent transactions by classifying whether a transaction is legitimate or suspicious based on various features like transaction amount, time, and location.
#
# Example: Detecting credit card fraud by building decision trees to identify patterns in transaction data (e.g., unusual spending behavior).
#
# 3. Marketing and Customer Segmentation
#
# Decision trees are frequently used in marketing to segment customers, optimize campaigns, and predict customer behavior.
#
# Customer Segmentation: Companies use decision trees to classify customers into distinct groups based on behavior, demographics, and preferences. This segmentation allows for targeted marketing.
#
# Example: Classifying customers into groups such as "high-value," "mid-value," and "low-value" based on purchase history and demographic data.
# Churn Prediction: Decision trees can help identify customers who are at risk of leaving (churning) by analyzing customer behavior and engagement metrics.
#
# Example: A telecom company might use a decision tree to predict which customers are likely to cancel their subscriptions based on factors like usage frequency, customer service interactions, and payment history.
# Marketing Campaigns: Decision trees can be used to determine which customers are most likely to respond to a particular marketing campaign, based on historical data.
#
# Example: Predicting which customers will respond to an email marketing campaign for a new product based on their past interactions and purchase patterns.
#
# 4. Retail and E-Commerce
#
# In retail, decision trees are used for sales predictions, inventory management, and customer recommendations.
#
# Sales Prediction: Retailers can use decision trees to predict future sales based on factors like seasonal trends, promotional events, and customer behavior.
#
# Example: Predicting the sales volume of a product based on previous sales, time of year, and promotions.
# Product Recommendations: E-commerce platforms use decision trees to recommend products to customers based on their browsing history, past purchases, and preferences.
#
# Example: Amazon’s recommendation system uses decision trees (along with other models) to suggest products that a customer might be interested in based on their past buying behavior.
# Inventory Management: Decision trees can help optimize inventory by predicting demand for products based on factors like seasonality, sales trends, and customer preferences.
#
# Example: A retail store using decision trees to predict how much stock of a product to order based on factors like historical sales, holidays, and promotions.
#
# 5. Manufacturing and Quality Control
#
# Decision trees play an important role in quality control, defect detection, and process optimization in manufacturing.
#
# Defect Detection: In the manufacturing industry, decision trees are used to classify products as defective or non-defective based on measurements, visual inspections, and other parameters.
#
# Example: Predicting whether a product will pass quality inspection based on features like size, weight, and color.
# Predictive Maintenance: Decision trees are used in predictive maintenance models to determine the likelihood of equipment failure based on sensor data and maintenance history. This helps companies perform maintenance before equipment breaks down.
#
# Example: Predicting when a machine will fail in a factory based on usage data and historical breakdowns, allowing the company to schedule maintenance ahead of time.
#
# 6. Natural Language Processing (NLP)
#
# Decision trees can also be applied in NLP tasks for text classification and sentiment analysis.
#
# Sentiment Analysis: Decision trees can classify the sentiment of a given text (positive, negative, neutral) based on features such as word frequency, sentiment-bearing words, and context.
#
# Example: Analyzing customer reviews or social media posts to classify whether the sentiment is positive or negative based on keywords and phrases.
# Text Classification: In tasks like spam detection, decision trees can classify whether an email or message is spam or not based on features such as subject, sender, and message content.
#
# Example: A spam filter classifying whether an email is spam or legitimate based on its content.
#
# 7. Energy and Environmental Applications
#
# Decision trees are used in energy management, environmental modeling, and climate studies.
#
# Energy Consumption Prediction: Decision trees can predict the energy consumption of households or buildings based on factors such as weather, time of day, and past consumption patterns.
#
# Example: Predicting household electricity usage based on the time of day, temperature, and the number of people in the household.
# Environmental Monitoring: Decision trees can help classify environmental data, such as air quality, based on features like pollution levels, weather conditions, and geographic location.
#
# Example: Classifying air quality in a city (e.g., good, moderate, hazardous) based on weather conditions, emissions data, and other environmental factors.
#
# 8. Sports Analytics
#
# In sports, decision trees are used to analyze player performance, predict match outcomes, and optimize team strategy.
#
# Player Performance: Decision trees can classify a player’s performance based on various factors such as physical attributes, past performance, and match conditions.
#
# Example: Predicting whether a player will score a goal in a football match based on features such as past performance, position, and opposition strength.
# Match Outcome Prediction: Decision trees can help predict the outcome of sports matches (win, lose, or draw) by considering factors like team statistics, player availability, and home/away status.
#
# Example: Predicting the outcome of a tennis match between two players based on their ranking, previous match statistics, and other relevant data.
#
# 9. Autonomous Vehicles
#
# In the field of autonomous vehicles, decision trees are used for decision-making and sensor data interpretation.
#
# Obstacle Detection and Avoidance: Decision trees can classify objects around the vehicle as obstacles or safe paths based on sensor data (e.g., radar, LiDAR, cameras).
#
# Example: Identifying and avoiding pedestrians, other vehicles, or obstacles in the path of an autonomous vehicle based on sensor inputs.
# Route Optimization: Decision trees can help determine the optimal route by evaluating factors like traffic, road conditions, and time of day.
#
# Example: Predicting the best route for an autonomous delivery vehicle based on real-time data.
#
# 10. Education and Student Performance
#
# In education, decision trees are used to predict student performance, dropout risk, and learning outcomes.
#
# Student Performance Prediction: Decision trees can predict whether a student will pass or fail based on factors like attendance, grades, study habits, and engagement.
#
# Example: Identifying students who are at risk of failing a course based on their performance in quizzes, assignments, and class participation.
# Dropout Prediction: Decision trees can be used to predict the likelihood of a student dropping out of school or university.
#
# Example: Predicting student dropout risk based on academic performance, socioeconomic status, and engagement with school activities.

# %% [markdown]
# **Question No16:** Write a Python program to train a Decision Tree Classifier on the Iris dataset and print the model accuracy.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# Print the model accuracy
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 100.00%

# %% [markdown]
# **Question No17:** Write a Python program to train a Decision Tree Classifier using Gini Impurity as the criterion and print the feature importances.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier with Gini Impurity as the criterion
clf = DecisionTreeClassifier(criterion='gini', random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Print the feature importances
print("Feature Importances:")
for feature, importance in zip(iris.feature_names, clf.feature_importances_):
    print(f"{feature}: {importance:.4f}")
# Out:
# Feature Importances:
# sepal length (cm): 0.0000
# sepal width (cm): 0.0191
# petal length (cm): 0.8933
# petal width (cm): 0.0876

# %% [markdown]
# **Question No18:** Write a Python program to train a Decision Tree Classifier using Entropy as the splitting criterion and print the model accuracy
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier with Entropy as the criterion
clf = DecisionTreeClassifier(criterion='entropy', random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# Print the model accuracy
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 97.78%

# %% [markdown]
# **Question No19:** Write a Python program to train a Decision Tree Regressor on a housing dataset and evaluate using Mean Squared Error (MSE)
#
# **Answer:**

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Load the California housing dataset
data = fetch_california_housing()
X = data.data  # Features
y = data.target  # Target values (house prices)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Regressor
regressor = DecisionTreeRegressor(random_state=42)

# Train the model on the training data
regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = regressor.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print the Mean Squared Error
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 0.53

# %% [markdown]
# **Question No20:** Write a Python program to train a Decision Tree Classifier and visualize the tree using graphviz
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Visualize the decision tree
dot_data = export_graphviz(clf, out_file=None, feature_names=iris.feature_names,
                           class_names=iris.target_names, filled=True, rounded=True, special_characters=True)

# Create a Graphviz source object and render the tree
graph = graphviz.Source(dot_data)
graph.render("iris_decision_tree")  # This will save the tree as a PDF
graph.view()  # This will open the decision tree in a default viewer
# Out:
# 'iris_decision_tree.pdf'

# %% [markdown]
# **Question No21:** Write a Python program to train a Decision Tree Classifier with a maximum depth of 3 and compare its accuracy with a fully grown tree.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier with a maximum depth of 3
clf_depth_3 = DecisionTreeClassifier(max_depth=3, random_state=42)

# Initialize the fully grown Decision Tree Classifier (no depth restriction)
clf_full_tree = DecisionTreeClassifier(random_state=42)

# Train both models on the training data
clf_depth_3.fit(X_train, y_train)
clf_full_tree.fit(X_train, y_train)

# Make predictions on the test data
y_pred_depth_3 = clf_depth_3.predict(X_test)
y_pred_full_tree = clf_full_tree.predict(X_test)

# Calculate the accuracy of both models
accuracy_depth_3 = accuracy_score(y_test, y_pred_depth_3)
accuracy_full_tree = accuracy_score(y_test, y_pred_full_tree)

# Print the model accuracies
print(f"Accuracy of Decision Tree with max depth 3: {accuracy_depth_3 * 100:.2f}%")
print(f"Accuracy of fully grown Decision Tree: {accuracy_full_tree * 100:.2f}%")
# Out:
# Accuracy of Decision Tree with max depth 3: 100.00%
# Accuracy of fully grown Decision Tree: 100.00%

# %% [markdown]
# **Question No22:** Write a Python program to train a Decision Tree Classifier using min_samples_split=5 and compare its accuracy with a default tree.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier with min_samples_split=5
clf_min_samples_split = DecisionTreeClassifier(min_samples_split=5, random_state=42)

# Initialize the default Decision Tree Classifier (no min_samples_split restriction)
clf_default = DecisionTreeClassifier(random_state=42)

# Train both models on the training data
clf_min_samples_split.fit(X_train, y_train)
clf_default.fit(X_train, y_train)

# Make predictions on the test data
y_pred_min_samples_split = clf_min_samples_split.predict(X_test)
y_pred_default = clf_default.predict(X_test)

# Calculate the accuracy of both models
accuracy_min_samples_split = accuracy_score(y_test, y_pred_min_samples_split)
accuracy_default = accuracy_score(y_test, y_pred_default)

# Print the model accuracies
print(f"Accuracy of Decision Tree with min_samples_split=5: {accuracy_min_samples_split * 100:.2f}%")
print(f"Accuracy of default Decision Tree: {accuracy_default * 100:.2f}%")
# Out:
# Accuracy of Decision Tree with min_samples_split=5: 100.00%
# Accuracy of default Decision Tree: 100.00%

# %% [markdown]
# **Question No23:** Write a Python program to apply feature scaling before training a Decision Tree Classifier and compare its accuracy with unscaled data.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Feature scaling (Standardization) - Apply scaling only to the features
scaler = StandardScaler()

# Fit the scaler on the training data and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform the test data using the same scaler (we only fit the scaler on the training data)
X_test_scaled = scaler.transform(X_test)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on unscaled data
clf.fit(X_train, y_train)
y_pred_unscaled = clf.predict(X_test)
accuracy_unscaled = accuracy_score(y_test, y_pred_unscaled)

# Train the model on scaled data
clf.fit(X_train_scaled, y_train)
y_pred_scaled = clf.predict(X_test_scaled)
accuracy_scaled = accuracy_score(y_test, y_pred_scaled)

# Print the model accuracies
print(f"Accuracy of Decision Tree with unscaled data: {accuracy_unscaled * 100:.2f}%")
print(f"Accuracy of Decision Tree with scaled data: {accuracy_scaled * 100:.2f}%")
# Out:
# Accuracy of Decision Tree with unscaled data: 100.00%
# Accuracy of Decision Tree with scaled data: 100.00%

# %% [markdown]
# **Question No24:** Write a Python program to train a Decision Tree Classifier using One-vs-Rest (OvR) strategy for multiclass classification
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels (3 classes)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Initialize the One-vs-Rest strategy using the Decision Tree Classifier
ovr_classifier = OneVsRestClassifier(dt_classifier)

# Train the model on the training data
ovr_classifier.fit(X_train, y_train)

# Make predictions on the test data
y_pred = ovr_classifier.predict(X_test)

# Calculate accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# Print the model accuracy
print(f"Accuracy of Decision Tree with One-vs-Rest strategy: {accuracy * 100:.2f}%")
# Out:
# Accuracy of Decision Tree with One-vs-Rest strategy: 100.00%

# %% [markdown]
# **Question No25:** Write a Python program to train a Decision Tree Classifier and display the feature importance scores.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Get feature importance scores
feature_importances = clf.feature_importances_

# Display the feature importance scores along with feature names
feature_names = iris.feature_names
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
})

# Sort the features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print the sorted feature importance scores
print("Feature importance scores:")
print(feature_importance_df)
# Out:
# Feature importance scores:
#              Feature  Importance
# 2  petal length (cm)    0.893264
# 3   petal width (cm)    0.087626
# 1   sepal width (cm)    0.019110
# 0  sepal length (cm)    0.000000

# %% [markdown]
# **Question No26:** Write a Python program to train a Decision Tree Regressor with max_depth=5 and compare its performance with an unrestricted tree
#
# **Answer:**

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Generate a synthetic regression dataset
X, y = make_regression(n_samples=1000, n_features=5, noise=0.1, random_state=42)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Regressor with max_depth=5
regressor_depth_5 = DecisionTreeRegressor(max_depth=5, random_state=42)

# Initialize the Decision Tree Regressor with no depth limit (unrestricted tree)
regressor_unrestricted = DecisionTreeRegressor(random_state=42)

# Train both models on the training data
regressor_depth_5.fit(X_train, y_train)
regressor_unrestricted.fit(X_train, y_train)

# Make predictions on the test data
y_pred_depth_5 = regressor_depth_5.predict(X_test)
y_pred_unrestricted = regressor_unrestricted.predict(X_test)

# Calculate Mean Squared Error (MSE) for both models
mse_depth_5 = mean_squared_error(y_test, y_pred_depth_5)
mse_unrestricted = mean_squared_error(y_test, y_pred_unrestricted)

# Print the MSE of both models
print(f"Mean Squared Error of Decision Tree with max_depth=5: {mse_depth_5:.4f}")
print(f"Mean Squared Error of unrestricted Decision Tree: {mse_unrestricted:.4f}")
# Out:
# Mean Squared Error of Decision Tree with max_depth=5: 1476.4113
# Mean Squared Error of unrestricted Decision Tree: 1062.7740

# %% [markdown]
# **Question No27:** Write a Python program to train a Decision Tree Classifier, apply Cost Complexity Pruning (CCP), and visualize its effect on accuracy.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model without pruning (Unpruned Tree)
clf.fit(X_train, y_train)

# Predict and calculate accuracy on the test data
y_pred_unpruned = clf.predict(X_test)
accuracy_unpruned = accuracy_score(y_test, y_pred_unpruned)

# Apply Cost Complexity Pruning (CCP)
path = clf.cost_complexity_pruning_path(X_train, y_train)

# Extract the alphas and the corresponding ccp_alphas
ccp_alphas = path.ccp_alphas

# Store the accuracies for different values of alpha
accuracies = []

# Train models for different values of alpha (from 0 to the maximum ccp_alpha)
for ccp_alpha in ccp_alphas:
    clf_pruned = DecisionTreeClassifier(random_state=42, ccp_alpha=ccp_alpha)
    clf_pruned.fit(X_train, y_train)
    y_pred_pruned = clf_pruned.predict(X_test)
    accuracies.append(accuracy_score(y_test, y_pred_pruned))

# Plot the effect of pruning on accuracy
plt.figure(figsize=(10, 6))
plt.plot(ccp_alphas, accuracies, marker='o', label="Test Accuracy vs CCP Alpha")
plt.axhline(y=accuracy_unpruned, color='r', linestyle='--', label="Unpruned Accuracy")
plt.xlabel("Alpha")
plt.ylabel("Accuracy")
plt.title("Effect of Cost Complexity Pruning on Decision Tree Accuracy")
plt.legend()
plt.show()

# Output the best alpha and the corresponding accuracy
best_alpha = ccp_alphas[accuracies.index(max(accuracies))]
best_accuracy = max(accuracies)
print(f"Best alpha: {best_alpha}")
print(f"Best accuracy with pruning: {best_accuracy:.4f}")
print(f"Accuracy without pruning: {accuracy_unpruned:.4f}")
# Out:
# Best alpha: 0.0
# Best accuracy with pruning: 1.0000
# Accuracy without pruning: 1.0000

# %% [markdown]
# **Question No28:** Write a Python program to train a Decision Tree Classifier and evaluate its performance using Precision, Recall, and F1-Score
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Calculate Precision, Recall, F1-Score for each class
precision = precision_score(y_test, y_pred, average=None)  # Precision per class
recall = recall_score(y_test, y_pred, average=None)  # Recall per class
f1 = f1_score(y_test, y_pred, average=None)  # F1 Score per class

# Print the evaluation metrics
print("Precision per class: ", precision)
print("Recall per class: ", recall)
print("F1-Score per class: ", f1)

# Calculate overall accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Overall Accuracy: {accuracy:.4f}")
# Out:
# Precision per class:  [1. 1. 1.]
# Recall per class:  [1. 1. 1.]
# F1-Score per class:  [1. 1. 1.]
# Overall Accuracy: 1.0000

# %% [markdown]
# **Question No29:** Write a Python program to train a Decision Tree Classifier and visualize the confusion matrix using seaborn
#
# **Answer:**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model on the training data
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a heatmap of the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.title("Confusion Matrix of Decision Tree Classifier")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %% [markdown]
# **Question No30:** Write a Python program to train a Decision Tree Classifier and use GridSearchCV to find the optimal values for max_depth and min_samples_split.
#
# **Answer:**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Define the parameter grid to search over
param_grid = {
    'max_depth': [3, 5, 10, None],  # Test different max_depth values
    'min_samples_split': [2, 5, 10]  # Test different min_samples_split values
}

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, n_jobs=-1)

# Perform the grid search to find the best parameters
grid_search.fit(X_train, y_train)

# Get the best parameters from GridSearchCV
best_params = grid_search.best_params_
print(f"Best hyperparameters found: {best_params}")

# Train the Decision Tree Classifier with the best hyperparameters
best_clf = grid_search.best_estimator_

# Make predictions on the test set
y_pred = best_clf.predict(X_test)

# Calculate the accuracy of the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the optimized Decision Tree Classifier: {accuracy:.4f}")
# Out:
# Best hyperparameters found: {'max_depth': 5, 'min_samples_split': 10}
# Accuracy of the optimized Decision Tree Classifier: 1.0000
